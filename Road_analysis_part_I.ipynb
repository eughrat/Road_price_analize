# %% [markdown]
# # ROAD COST ANALYSIS
#
# ## PART I - DATA PREPARATION

# %% [markdown]
# ### Introduction
# Continuing data analysis project we will look at the cost of road construction in Poland. It is said that road construction in Poland is much more expensive than in neighboring countries and the quality of the new routes does not meet the requirements of users.
#
# We will check the list of elements of newly build or rebuilt roads and what road elements contribute the most to the high cost of roads in Poland and what does it look like from the inside.
#
# The analysis will be carried out on the basis of real data for which the names of the roads covered by the analysis have been changed.
#
# The input material are pdf files obtained from a reputable polish construction company, the explanation of which is presented below.
#
# The original data contains the following columns:
#
# * 'Lp.': Ordinal number
# * 'CPV': Central Product Classification code
# * 'Numer Specyfikacji Technicznej': Technical Specification code
# * 'Elementy rozliczeniowe': Billing elements
# * 'Jednostka': Measure unit
# * 'Ilosc': quantity
# * 'Cena jedn': Unit price
# * 'Wartosc calkowita': Total value
# * 'Droga': Road number
# * 'Rok': Year of construction
# * 'Kategoria': Category of construction works

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np

from functions.pdf_tools import pdf_reader, pdf_cleaner, match_category

# %% [markdown]
# **Read pdf files**

# %%
road_data = pdf_reader('..\Projekt_Analiza_Danych\DATA\*.pdf')
# Out:
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']
# C:\Users\mpiernicki\Desktop\Projekt_Analiza_Danych\functions\pdf_tools.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_cl['Dlugosc_drogi'] = report_cl[report_cl['Elementy_rozliczeniowe'].str.contains("Odtworzenie trasy i punktów wysokościowych")]['Ilosc']

# %% [markdown]
# **Initial data clean**

# %%
road_data = pdf_cleaner(road_data)

# %% [markdown]
# **Checking the basic informations of the DataFrame**

# %%
road_data.head()
# Out:
#                                Elementy_rozliczeniowe Jednostka   Ilosc  \
# 14  Odtworzenie trasy i punktów wysokościowych wra...        km   24.24
# 16  Ścinanie drzew śr. od 20 do 35 cm wraz z karcz...      szt.  669.00
# 17  Ścinanie drzew śr. od 36 do 45 cm wraz z karcz...      szt.   77.00
# 18  Ścinanie drzew śr. 46-55 cm wraz z karczowanie...      szt.   58.00
# 19  Ścinanie drzew śr. od 56 do 65 cm wraz z karcz...      szt.   59.00
#
#    Cena_jedn Wartosc_calkowita   Droga   Rok              Kategoria  \
# 14  17413.58         422005.18  DK12ZW  2019  ROBOTY PRZYGOTOWAWCZE
# 16    370.40         247700.08  DK12ZW  2019  ROBOTY PRZYGOTOWAWCZE
# 17    529.66          40684.20  DK12ZW  2019  ROBOTY PRZYGOTOWAWCZE
# 18    724.21          41904.41  DK12ZW  2019  ROBOTY PRZYGOTOWAWCZE
# 19    874.60          51501.39  DK12ZW  2019  ROBOTY PRZYGOTOWAWCZE
#
#    Dlugosc_drogi
# 14         24.24
# 16         24.24
# 17         24.24
# 18         24.24
# 19         24.24

# %%
road_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 14 to 15
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Elementy_rozliczeniowe  2097 non-null   object
#  1   Jednostka               2097 non-null   object
#  2   Ilosc                   2097 non-null   object
#  3   Cena_jedn               2097 non-null   object
#  4   Wartosc_calkowita       2097 non-null   object
#  5   Droga                   2097 non-null   object
#  6   Rok                     2097 non-null   object
#  7   Kategoria               2097 non-null   object
#  8   Dlugosc_drogi           2097 non-null   object
# dtypes: object(9)
# memory usage: 163.8+ KB

# %%
road_data.describe()
# Out:
#        Elementy_rozliczeniowe Jednostka Ilosc Cena_jedn Wartosc_calkowita  \
# count                    2097      2097  2097      2097              2097
# unique                    644        12  1482       769              1967
# top               Tablice "E"        m2  1.00  16851.85          16751.85
# freq                       19       731   122        15                19
#
#        Droga   Rok              Kategoria Dlugosc_drogi
# count   2097  2097                   2097          2097
# unique    19     7                     14            19
# top     DK77  2021  ROBOTY PRZYGOTOWAWCZE         24.24
# freq     156   538                    563           154

# %%
set(road_data['Cena_jedn'].map(type))
# Out:
# {str}

# %%
set(road_data['Ilosc'].map(type))
# Out:
# {str}

# %%
set(road_data['Wartosc_calkowita'].map(type))
# Out:
# {str}

# %%
set(road_data['Dlugosc_drogi'].map(type))
# Out:
# {str}

# %%
set(road_data['Rok'].map(type))
# Out:
# {str}

# %%
road_data['Kategoria'].value_counts()
# Out:
# ROBOTY PRZYGOTOWAWCZE                                 563
# OZNAKOWANIA DRÓG I URZĄDZENIA BEZPIECZEŃSTWA RUCHU    343
# PODBUDOWY                                             256
# NAWIERZCHNIE                                          191
# ZIELEŃ DROGOWA                                        169
# ELEMENTY ULIC                                         151
# ROBOTY WYKOŃCZENIOWE                                  139
# WARUNKI OGÓLNE                                         85
# ROBOTY ZIEMNE                                          83
# ODWODNIENIE KORPUSU DROGOWEGO                          76
# INNE ROBOTY                                            36
# WYMAGANIA OGÓLNE                                        3
# WARSTWA MROZOOCHRONNA Z MIESZANKI NIEZWIĄZANEJ          1
# OZNAKOWANIA DRÓG I URZĄDZENIA                           1
# Name: Kategoria, dtype: int64

# %% [markdown]
# **Note**
#
# As you can see above,the "Ilosc, Cena_jedn, Wartosc_calkowita, Dlugosc_drogi and Rok" columns contains wrong data type, we will convert them to float and DateTime data type. What is more the "Kategoria" column contain incomplete category names. In the next few steps we will fix these errors.

# %% [markdown]
# **Cleaning the "Kategoria" column**

# %%
road_data['Kategoria_robot'] = road_data['Kategoria'].apply(match_category)

# %%
road_data.drop('Kategoria', inplace=True, axis=1)

# %%
road_data
# Out:
#                                Elementy_rozliczeniowe Jednostka   Ilosc  \
# 14  Odtworzenie trasy i punktów wysokościowych wra...        km   24.24
# 16  Ścinanie drzew śr. od 20 do 35 cm wraz z karcz...      szt.  669.00
# 17  Ścinanie drzew śr. od 36 do 45 cm wraz z karcz...      szt.   77.00
# 18  Ścinanie drzew śr. 46-55 cm wraz z karczowanie...      szt.   58.00
# 19  Ścinanie drzew śr. od 56 do 65 cm wraz z karcz...      szt.   59.00
# ..                                                ...       ...     ...
# 6                         Mieszanka roślin rabatowych        m2  100.00
# 10  Ścianki oporowe typu "L" - gr 25 cm, wysokość ...         m   51.00
# 11  Ścianki oporowe typu "L" - gr. 10 cm, wysokość...         m    8.00
# 13  Wykonanie schodów i zejść do posesji z element...        m2   25.16
# 15  Pomiar powykonawczy zrealizowanych obiektów dr...        km   12.98
#
#    Cena_jedn Wartosc_calkowita    Droga   Rok Dlugosc_drogi  \
# 14  17413.58         422005.18   DK12ZW  2019         24.24
# 16    370.40         247700.08   DK12ZW  2019         24.24
# 17    529.66          40684.20   DK12ZW  2019         24.24
# 18    724.21          41904.41   DK12ZW  2019         24.24
# 19    874.60          51501.39   DK12ZW  2019         24.24
# ..       ...               ...      ...   ...           ...
# 6      50.00           5000.00  DW919SK  2015         12.98
# 10   1024.40          52244.40  DW919SK  2015         12.98
# 11    274.30           2194.40  DW919SK  2015         12.98
# 13    246.34           6198.04  DW919SK  2015         12.98
# 15  29829.22         387064.26  DW919SK  2015         12.98
#
#           Kategoria_robot
# 14  ROBOTY PRZYGOTOWAWCZE
# 16  ROBOTY PRZYGOTOWAWCZE
# 17  ROBOTY PRZYGOTOWAWCZE
# 18  ROBOTY PRZYGOTOWAWCZE
# 19  ROBOTY PRZYGOTOWAWCZE
# ..                    ...
# 6          ZIELEN DROGOWA
# 10            INNE ROBOTY
# 11            INNE ROBOTY
# 13            INNE ROBOTY
# 15            INNE ROBOTY
#
# [2097 rows x 9 columns]

# %%
road_data['Ilosc'] = pd.to_numeric(road_data['Ilosc'],errors='coerce')

# %% [markdown]
# **Cleaning the "Ilosc", "Cena_jedn", "Wartosc_calkowita" and "Dlugosc_drogi"columns**

# %%
road_data['Ilosc'] = pd.to_numeric(road_data['Ilosc'],errors='coerce')

# %%
road_data['Cena_jedn'] = pd.to_numeric(road_data['Cena_jedn'],errors='coerce')

# %%
road_data['Wartosc_calkowita'] = pd.to_numeric(road_data['Wartosc_calkowita'],errors='coerce')

# %%
road_data['Dlugosc_drogi'] = pd.to_numeric(road_data['Dlugosc_drogi'],errors='coerce')

# %% [markdown]
# **Cleaning the "Rok" column**

# %%
road_data['Rok'] = pd.to_numeric(road_data['Rok'],errors='coerce')

# %%
road_data['Rok'] = pd.to_datetime(road_data['Rok'],format='%Y')

# %%
road_data
# Out:
#                                Elementy_rozliczeniowe Jednostka   Ilosc  \
# 14  Odtworzenie trasy i punktów wysokościowych wra...        km   24.24
# 16  Ścinanie drzew śr. od 20 do 35 cm wraz z karcz...      szt.  669.00
# 17  Ścinanie drzew śr. od 36 do 45 cm wraz z karcz...      szt.   77.00
# 18  Ścinanie drzew śr. 46-55 cm wraz z karczowanie...      szt.   58.00
# 19  Ścinanie drzew śr. od 56 do 65 cm wraz z karcz...      szt.   59.00
# ..                                                ...       ...     ...
# 6                         Mieszanka roślin rabatowych        m2  100.00
# 10  Ścianki oporowe typu "L" - gr 25 cm, wysokość ...         m   51.00
# 11  Ścianki oporowe typu "L" - gr. 10 cm, wysokość...         m    8.00
# 13  Wykonanie schodów i zejść do posesji z element...        m2   25.16
# 15  Pomiar powykonawczy zrealizowanych obiektów dr...        km   12.98
#
#     Cena_jedn  Wartosc_calkowita    Droga        Rok  Dlugosc_drogi  \
# 14   17413.58          422005.18   DK12ZW 2019-01-01          24.24
# 16     370.40          247700.08   DK12ZW 2019-01-01          24.24
# 17     529.66           40684.20   DK12ZW 2019-01-01          24.24
# 18     724.21           41904.41   DK12ZW 2019-01-01          24.24
# 19     874.60           51501.39   DK12ZW 2019-01-01          24.24
# ..        ...                ...      ...        ...            ...
# 6       50.00            5000.00  DW919SK 2015-01-01          12.98
# 10    1024.40           52244.40  DW919SK 2015-01-01          12.98
# 11     274.30            2194.40  DW919SK 2015-01-01          12.98
# 13     246.34            6198.04  DW919SK 2015-01-01          12.98
# 15   29829.22          387064.26  DW919SK 2015-01-01          12.98
#
#           Kategoria_robot
# 14  ROBOTY PRZYGOTOWAWCZE
# 16  ROBOTY PRZYGOTOWAWCZE
# 17  ROBOTY PRZYGOTOWAWCZE
# 18  ROBOTY PRZYGOTOWAWCZE
# 19  ROBOTY PRZYGOTOWAWCZE
# ..                    ...
# 6          ZIELEN DROGOWA
# 10            INNE ROBOTY
# 11            INNE ROBOTY
# 13            INNE ROBOTY
# 15            INNE ROBOTY
#
# [2097 rows x 9 columns]

# %%
road_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 14 to 15
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Elementy_rozliczeniowe  2097 non-null   object
#  1   Jednostka               2097 non-null   object
#  2   Ilosc                   2095 non-null   float64
#  3   Cena_jedn               2097 non-null   float64
#  4   Wartosc_calkowita       2095 non-null   float64
#  5   Droga                   2097 non-null   object
#  6   Rok                     2097 non-null   datetime64[ns]
#  7   Dlugosc_drogi           2097 non-null   float64
#  8   Kategoria_robot         2097 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 163.8+ KB

# %%
road_data['Kategoria_drogi'] = road_data['Droga'].str[0:2].apply(lambda x:
                                                                 ('Powiatowa' if x=='DP'
                                                                  else 'Krajowa' if x=='DK'
                                                                  else 'Wojewodzka'))

# %%
road_data
# Out:
#                                Elementy_rozliczeniowe Jednostka   Ilosc  \
# 14  Odtworzenie trasy i punktów wysokościowych wra...        km   24.24
# 16  Ścinanie drzew śr. od 20 do 35 cm wraz z karcz...      szt.  669.00
# 17  Ścinanie drzew śr. od 36 do 45 cm wraz z karcz...      szt.   77.00
# 18  Ścinanie drzew śr. 46-55 cm wraz z karczowanie...      szt.   58.00
# 19  Ścinanie drzew śr. od 56 do 65 cm wraz z karcz...      szt.   59.00
# ..                                                ...       ...     ...
# 6                         Mieszanka roślin rabatowych        m2  100.00
# 10  Ścianki oporowe typu "L" - gr 25 cm, wysokość ...         m   51.00
# 11  Ścianki oporowe typu "L" - gr. 10 cm, wysokość...         m    8.00
# 13  Wykonanie schodów i zejść do posesji z element...        m2   25.16
# 15  Pomiar powykonawczy zrealizowanych obiektów dr...        km   12.98
#
#     Cena_jedn  Wartosc_calkowita    Droga        Rok  Dlugosc_drogi  \
# 14   17413.58          422005.18   DK12ZW 2019-01-01          24.24
# 16     370.40          247700.08   DK12ZW 2019-01-01          24.24
# 17     529.66           40684.20   DK12ZW 2019-01-01          24.24
# 18     724.21           41904.41   DK12ZW 2019-01-01          24.24
# 19     874.60           51501.39   DK12ZW 2019-01-01          24.24
# ..        ...                ...      ...        ...            ...
# 6       50.00            5000.00  DW919SK 2015-01-01          12.98
# 10    1024.40           52244.40  DW919SK 2015-01-01          12.98
# 11     274.30            2194.40  DW919SK 2015-01-01          12.98
# 13     246.34            6198.04  DW919SK 2015-01-01          12.98
# 15   29829.22          387064.26  DW919SK 2015-01-01          12.98
#
#           Kategoria_robot Kategoria_drogi
# 14  ROBOTY PRZYGOTOWAWCZE         Krajowa
# 16  ROBOTY PRZYGOTOWAWCZE         Krajowa
# 17  ROBOTY PRZYGOTOWAWCZE         Krajowa
# 18  ROBOTY PRZYGOTOWAWCZE         Krajowa
# 19  ROBOTY PRZYGOTOWAWCZE         Krajowa
# ..                    ...             ...
# 6          ZIELEN DROGOWA      Wojewodzka
# 10            INNE ROBOTY      Wojewodzka
# 11            INNE ROBOTY      Wojewodzka
# 13            INNE ROBOTY      Wojewodzka
# 15            INNE ROBOTY      Wojewodzka
#
# [2097 rows x 10 columns]

# %%
road_data['Kategoria_drogi'].value_counts()
# Out:
# Wojewodzka    1307
# Krajowa        688
# Powiatowa      102
# Name: Kategoria_drogi, dtype: int64

# %% [markdown]
# **Note**
#
# It can be seen that the product of the "Ilosc" and "Cena_jedn" columns does not equal to the values in the column "Wartosc_calkowita", let's fix that.

# %%
road_data['Wartosc_calkowita'] = road_data['Ilosc'] * road_data['Cena_jedn']

# %%
road_data
# Out:
#                                Elementy_rozliczeniowe Jednostka   Ilosc  \
# 14  Odtworzenie trasy i punktów wysokościowych wra...        km   24.24
# 16  Ścinanie drzew śr. od 20 do 35 cm wraz z karcz...      szt.  669.00
# 17  Ścinanie drzew śr. od 36 do 45 cm wraz z karcz...      szt.   77.00
# 18  Ścinanie drzew śr. 46-55 cm wraz z karczowanie...      szt.   58.00
# 19  Ścinanie drzew śr. od 56 do 65 cm wraz z karcz...      szt.   59.00
# ..                                                ...       ...     ...
# 6                         Mieszanka roślin rabatowych        m2  100.00
# 10  Ścianki oporowe typu "L" - gr 25 cm, wysokość ...         m   51.00
# 11  Ścianki oporowe typu "L" - gr. 10 cm, wysokość...         m    8.00
# 13  Wykonanie schodów i zejść do posesji z element...        m2   25.16
# 15  Pomiar powykonawczy zrealizowanych obiektów dr...        km   12.98
#
#     Cena_jedn  Wartosc_calkowita    Droga        Rok  Dlugosc_drogi  \
# 14   17413.58        422105.1792   DK12ZW 2019-01-01          24.24
# 16     370.40        247797.6000   DK12ZW 2019-01-01          24.24
# 17     529.66         40783.8200   DK12ZW 2019-01-01          24.24
# 18     724.21         42004.1800   DK12ZW 2019-01-01          24.24
# 19     874.60         51601.4000   DK12ZW 2019-01-01          24.24
# ..        ...                ...      ...        ...            ...
# 6       50.00          5000.0000  DW919SK 2015-01-01          12.98
# 10    1024.40         52244.4000  DW919SK 2015-01-01          12.98
# 11     274.30          2194.4000  DW919SK 2015-01-01          12.98
# 13     246.34          6197.9144  DW919SK 2015-01-01          12.98
# 15   29829.22        387183.2756  DW919SK 2015-01-01          12.98
#
#           Kategoria_robot Kategoria_drogi
# 14  ROBOTY PRZYGOTOWAWCZE         Krajowa
# 16  ROBOTY PRZYGOTOWAWCZE         Krajowa
# 17  ROBOTY PRZYGOTOWAWCZE         Krajowa
# 18  ROBOTY PRZYGOTOWAWCZE         Krajowa
# 19  ROBOTY PRZYGOTOWAWCZE         Krajowa
# ..                    ...             ...
# 6          ZIELEN DROGOWA      Wojewodzka
# 10            INNE ROBOTY      Wojewodzka
# 11            INNE ROBOTY      Wojewodzka
# 13            INNE ROBOTY      Wojewodzka
# 15            INNE ROBOTY      Wojewodzka
#
# [2097 rows x 10 columns]

# %% [markdown]
# **Note**
#
# We still dont know the lenght of analized roads, so their cost not reliable. Let's bring all the costs down to the cost of the 1 km of the road
#
# We know that the cells that contains sentence "Odtworzenie trasy i punktów wysokościowych..." in column "Elementy_rozliczenione" contains information about the lenght of the analized roads. We used it at the begining (def pdf_reader) to bring all the costs down to the cost of the 1 km of the road

# %%
road_data['Cena_jedn_per_km'] = road_data['Cena_jedn'] / road_data['Dlugosc_drogi']

# %%
road_data['Wartosc_calkowita_per_km'] = road_data['Wartosc_calkowita'] / road_data['Dlugosc_drogi']

# %%
road_data
# Out:
#                                Elementy_rozliczeniowe Jednostka   Ilosc  \
# 14  Odtworzenie trasy i punktów wysokościowych wra...        km   24.24
# 16  Ścinanie drzew śr. od 20 do 35 cm wraz z karcz...      szt.  669.00
# 17  Ścinanie drzew śr. od 36 do 45 cm wraz z karcz...      szt.   77.00
# 18  Ścinanie drzew śr. 46-55 cm wraz z karczowanie...      szt.   58.00
# 19  Ścinanie drzew śr. od 56 do 65 cm wraz z karcz...      szt.   59.00
# ..                                                ...       ...     ...
# 6                         Mieszanka roślin rabatowych        m2  100.00
# 10  Ścianki oporowe typu "L" - gr 25 cm, wysokość ...         m   51.00
# 11  Ścianki oporowe typu "L" - gr. 10 cm, wysokość...         m    8.00
# 13  Wykonanie schodów i zejść do posesji z element...        m2   25.16
# 15  Pomiar powykonawczy zrealizowanych obiektów dr...        km   12.98
#
#     Cena_jedn  Wartosc_calkowita    Droga        Rok  Dlugosc_drogi  \
# 14   17413.58        422105.1792   DK12ZW 2019-01-01          24.24
# 16     370.40        247797.6000   DK12ZW 2019-01-01          24.24
# 17     529.66         40783.8200   DK12ZW 2019-01-01          24.24
# 18     724.21         42004.1800   DK12ZW 2019-01-01          24.24
# 19     874.60         51601.4000   DK12ZW 2019-01-01          24.24
# ..        ...                ...      ...        ...            ...
# 6       50.00          5000.0000  DW919SK 2015-01-01          12.98
# 10    1024.40         52244.4000  DW919SK 2015-01-01          12.98
# 11     274.30          2194.4000  DW919SK 2015-01-01          12.98
# 13     246.34          6197.9144  DW919SK 2015-01-01          12.98
# 15   29829.22        387183.2756  DW919SK 2015-01-01          12.98
#
#           Kategoria_robot Kategoria_drogi  Cena_jedn_per_km  \
# 14  ROBOTY PRZYGOTOWAWCZE         Krajowa        718.382013
# 16  ROBOTY PRZYGOTOWAWCZE         Krajowa         15.280528
# 17  ROBOTY PRZYGOTOWAWCZE         Krajowa         21.850660
# 18  ROBOTY PRZYGOTOWAWCZE         Krajowa         29.876650
# 19  ROBOTY PRZYGOTOWAWCZE         Krajowa         36.080858
# ..                    ...             ...               ...
# 6          ZIELEN DROGOWA      Wojewodzka          3.852080
# 10            INNE ROBOTY      Wojewodzka         78.921418
# 11            INNE ROBOTY      Wojewodzka         21.132512
# 13            INNE ROBOTY      Wojewodzka         18.978428
# 15            INNE ROBOTY      Wojewodzka       2298.090909
#
#     Wartosc_calkowita_per_km
# 14              17413.580000
# 16              10222.673267
# 17               1682.500825
# 18               1732.845710
# 19               2128.770627
# ..                       ...
# 6                 385.208012
# 10               4024.992296
# 11                169.060092
# 13                477.497257
# 15              29829.220000
#
# [2097 rows x 12 columns]

# %% [markdown]
# **Note**
#
# Okey we finished our data preparation let's save it to excel file for further data analysis in second part of the project.

# %%
road_data.to_excel('..\Projekt_Analiza_Danych\DATA\Road_cost_analysis.xlsx',
                                             sheet_name='Road_cost_analysis',
                                             index=False)
