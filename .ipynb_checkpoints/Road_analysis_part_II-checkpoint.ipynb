# %%
import pandas as pd

# %%
road_data = pd.read_excel('..\Projekt_Analiza_Danych\DATA\Road_cost_analysis.xlsx')

# %%
road_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2096 entries, 0 to 2095
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Elementy_rozliczeniowe    2096 non-null   object
#  1   Jednostka                 2096 non-null   object
#  2   Ilosc                     2094 non-null   float64
#  3   Cena_jedn                 2096 non-null   float64
#  4   Wartosc_calkowita         2094 non-null   float64
#  5   Droga                     2096 non-null   object
#  6   Rok                       2096 non-null   datetime64[ns]
#  7   Dlugosc_drogi             2096 non-null   float64
#  8   Kategoria_robot           2096 non-null   object
#  9   Kategoria_drogi           2096 non-null   object
#  10  Cena_jedn_per_km          2096 non-null   float64
#  11  Wartosc_calkowita_per_km  1900 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(5)
# memory usage: 196.6+ KB

# %%
road_data
# Out:
#                                  Elementy_rozliczeniowe Jednostka   Ilosc  \
# 0     Odtworzenie trasy i punktów wysokościowych wra...        km   24.24
# 1     Ścinanie drzew śr. od 20 do 35 cm wraz z karcz...      szt.  669.00
# 2     Ścinanie drzew śr. od 36 do 45 cm wraz z karcz...      szt.   77.00
# 3     Ścinanie drzew śr. 46-55 cm wraz z karczowanie...      szt.   58.00
# 4     Ścinanie drzew śr. od 56 do 65 cm wraz z karcz...      szt.   59.00
# ...                                                 ...       ...     ...
# 2091                        Mieszanka roślin rabatowych        m2  100.00
# 2092  Ścianki oporowe typu "L" - gr 25 cm, wysokość ...         m   51.00
# 2093  Ścianki oporowe typu "L" - gr. 10 cm, wysokość...         m    8.00
# 2094  Wykonanie schodów i zejść do posesji z element...        m2   25.16
# 2095  Pomiar powykonawczy zrealizowanych obiektów dr...        km   12.98
#
#       Cena_jedn  Wartosc_calkowita    Droga        Rok  Dlugosc_drogi  \
# ...
